# %%
import cv2
import numpy as np
from ultralytics import YOLO
from ultralytics.utils.plotting import Annotator, colors

# %%
import os
import cv2

def yolowebcam(model, output_file='yolo-output.mp4', fps=20.0, frame_size=(640, 480)):
    # Open the webcam
    vc = cv2.VideoCapture(0)
    vc.set(cv2.CAP_PROP_FRAME_WIDTH, frame_size[0])
    vc.set(cv2.CAP_PROP_FRAME_HEIGHT, frame_size[1])

    # Define variables for VideoWriter initialization
    out = None
    recording = False
    output_path = os.path.abspath(output_file)  # Get the absolute path of the output file

    # Automatically start recording
    # Define the codec and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Using 'mp4v' codec
    out = cv2.VideoWriter(output_file, fourcc, fps, frame_size)

    # Check if VideoWriter opened successfully
    if not out.isOpened():
        print("Failed to open VideoWriter")
        return  # Exit the function if VideoWriter fails
    else:
        recording = True
        print(f"Recording started... Saving video to: {output_path}")

    while True:
        ret, frame = vc.read()
        if not ret:
            print("Failed to capture frame")
            break

        # Run YOLO inference
        results = model(frame)

        # Create an Annotator object
        annotator = Annotator(frame)

        # Process results
        for r in results:
            boxes = r.boxes
            print(f"Detected {len(boxes)} objects")  # Debugging info

            for box in boxes:
                # Get box coordinates
                b = box.xyxy[0].cpu().numpy().astype(int)
                # Get class and confidence
                c = int(box.cls)
                conf = float(box.conf)

                # Draw box and label
                label = f'{model.names[c]} {conf:.2f}'
                color = colors(c, True)
                annotator.box_label(b, label, color=color)

                print(f"Box: {b}, Class: {model.names[c]}, Confidence: {conf:.2f}")  # Debugging info

        # Display the annotated frame
        annotated_frame = annotator.result()

        # Show the frame
        cv2.imshow("YOLO Webcam", annotated_frame)

        # Write the frame to the output file
        if recording and out is not None:
            # Ensure the frame size matches the VideoWriter frame size
            resized_frame = cv2.resize(annotated_frame, frame_size)
            out.write(resized_frame)
            print("Frame written to output file")  # Debugging info

        # Capture key press
        key = cv2.waitKey(1) & 0xFF

        # Check if 'q' is pressed to stop
        if key == ord('q'):
            print("Recording stopped by user")
            break

    # Release resources
    vc.release()
    if out is not None:
        out.release()
        # Verify if the file was created
        if os.path.exists(output_path) and os.path.getsize(output_path) > 0:
            print(f"Recording stopped and video saved at {output_path}")
        else:
            print(f"Failed to save the video or the file is empty at {output_path}")
    cv2.destroyAllWindows()

# %%
model = YOLO('./best.pt')
yolowebcam(model)
# Out:
# Recording started... Saving video to: c:\Users\alway\OneDrive\Documents\GitHub\Applied-AI\hw2\yolo\yolo-output.mp4
#
# 0: 480x640 1 person, 68.8ms
# Speed: 15.0ms preprocess, 68.8ms inference, 213.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 92  98 640 479], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 20.1ms
# Speed: 18.1ms preprocess, 20.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [116 106 639 479], Class: person, Confidence: 0.79
# Frame written to output file
#
# 0: 480x640 1 person, 12.5ms
# Speed: 6.7ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [116 106 639 479], Class: person, Confidence: 0.79
# Frame written to output file
#
# 0: 480x640 1 person, 12.6ms
# Speed: 7.6ms preprocess, 12.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 97 106 640 479], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 99 106 640 479], Class: person, Confidence: 0.67
# Box: [  1 287 640 478], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 22.0ms
# Speed: 1.8ms preprocess, 22.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 99 106 640 479], Class: person, Confidence: 0.67
# Box: [  1 287 640 478], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 79 105 640 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 22.1ms
# Speed: 3.0ms preprocess, 22.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 79 105 640 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 20.6ms
# Speed: 3.0ms preprocess, 20.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 92 105 640 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 53 105 639 479], Class: person, Confidence: 0.66
# Box: [  1 200 637 478], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 53 105 639 479], Class: person, Confidence: 0.66
# Box: [  1 200 637 478], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 25.5ms
# Speed: 2.6ms preprocess, 25.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 64 105 639 479], Class: person, Confidence: 0.68
# Box: [  1 148 638 478], Class: bed, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.3ms
# Speed: 1.0ms preprocess, 16.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 64 105 639 479], Class: person, Confidence: 0.68
# Box: [  1 148 638 478], Class: bed, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 14.1ms
# Speed: 1.5ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 67 104 640 479], Class: person, Confidence: 0.58
# Box: [  1 288 638 479], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 22.4ms
# Speed: 2.5ms preprocess, 22.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 67 104 640 479], Class: person, Confidence: 0.58
# Box: [  1 288 638 479], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 17.1ms
# Speed: 3.7ms preprocess, 17.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 52 103 640 479], Class: person, Confidence: 0.61
# Box: [  1 226 637 479], Class: bed, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 23.5ms
# Speed: 3.1ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 64 104 639 479], Class: person, Confidence: 0.59
# Box: [  1 240 637 479], Class: bed, Confidence: 0.41
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 29.5ms
# Speed: 3.0ms preprocess, 29.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 64 104 639 479], Class: person, Confidence: 0.59
# Box: [  1 240 637 479], Class: bed, Confidence: 0.41
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 19.5ms
# Speed: 4.0ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 59 105 639 479], Class: person, Confidence: 0.59
# Box: [  1 194 636 478], Class: bed, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 59 105 639 479], Class: person, Confidence: 0.59
# Box: [  1 194 636 478], Class: bed, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 89 106 640 479], Class: person, Confidence: 0.66
# Box: [  2 210 637 478], Class: bed, Confidence: 0.33
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [104 105 639 479], Class: person, Confidence: 0.57
# Box: [  1 287 640 479], Class: bed, Confidence: 0.46
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 33.6ms
# Speed: 4.0ms preprocess, 33.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [104 105 639 479], Class: person, Confidence: 0.57
# Box: [  1 287 640 479], Class: bed, Confidence: 0.46
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 11.9ms
# Speed: 0.0ms preprocess, 11.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 41 103 639 479], Class: person, Confidence: 0.53
# Box: [  1 287 639 479], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 41 103 639 479], Class: person, Confidence: 0.53
# Box: [  1 287 639 479], Class: bed, Confidence: 0.38
# Frame written to output file
#
# 0: 480x640 1 person, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 105 640 479], Class: person, Confidence: 0.65
# Frame written to output file
#
# 0: 480x640 1 person, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 105 640 479], Class: person, Confidence: 0.65
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  0 106 640 480], Class: person, Confidence: 0.65
# Box: [  1 123 636 478], Class: bed, Confidence: 0.26
# Box: [  1 288 638 479], Class: bed, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  0 106 640 480], Class: person, Confidence: 0.65
# Box: [  1 123 636 478], Class: bed, Confidence: 0.26
# Box: [  1 288 638 479], Class: bed, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 34 107 639 479], Class: person, Confidence: 0.51
# Box: [  1 289 640 479], Class: bed, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 bed, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  2 111 638 479], Class: person, Confidence: 0.50
# Box: [  2 289 640 479], Class: bed, Confidence: 0.42
# Box: [  0 285 640 479], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 bed, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  2 111 638 479], Class: person, Confidence: 0.50
# Box: [  2 289 640 479], Class: bed, Confidence: 0.42
# Box: [  0 285 640 479], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 couch, 1 bed, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 4 objects
# Box: [ 21 108 639 479], Class: person, Confidence: 0.44
# Box: [  0 264 635 479], Class: bed, Confidence: 0.34
# Box: [  0 283 640 479], Class: couch, Confidence: 0.27
# Box: [232 109 640 480], Class: person, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 couch, 1 bed, 29.1ms
# Speed: 1.0ms preprocess, 29.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 4 objects
# Box: [ 21 108 639 479], Class: person, Confidence: 0.44
# Box: [  0 264 635 479], Class: bed, Confidence: 0.34
# Box: [  0 283 640 479], Class: couch, Confidence: 0.27
# Box: [232 109 640 480], Class: person, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 15.8ms
# Speed: 2.1ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  2 289 640 479], Class: bed, Confidence: 0.49
# Box: [  0 108 640 479], Class: person, Confidence: 0.40
# Box: [212 108 640 480], Class: person, Confidence: 0.25
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 19.2ms
# Speed: 1.0ms preprocess, 19.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  2 289 640 479], Class: bed, Confidence: 0.49
# Box: [  0 108 640 479], Class: person, Confidence: 0.40
# Box: [212 108 640 480], Class: person, Confidence: 0.25
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 9.7ms
# Speed: 1.6ms preprocess, 9.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 41 109 639 479], Class: person, Confidence: 0.39
# Box: [  2 290 640 479], Class: bed, Confidence: 0.39
# Box: [240 110 639 480], Class: person, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 108 640 479], Class: person, Confidence: 0.61
# Frame written to output file
#
# 0: 480x640 1 person, 21.6ms
# Speed: 3.0ms preprocess, 21.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 108 640 479], Class: person, Confidence: 0.61
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.7ms
# Speed: 3.0ms preprocess, 16.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 23 108 640 479], Class: person, Confidence: 0.57
# Box: [  1 174 636 478], Class: bed, Confidence: 0.37
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 15.2ms
# Speed: 2.0ms preprocess, 15.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 23 108 640 479], Class: person, Confidence: 0.57
# Box: [  1 174 636 478], Class: bed, Confidence: 0.37
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 toothbrush, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [463 288 583 361], Class: toothbrush, Confidence: 0.65
# Box: [ 33 108 640 479], Class: person, Confidence: 0.58
# Box: [  0 217 636 478], Class: bed, Confidence: 0.33
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 toothbrush, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [463 288 583 361], Class: toothbrush, Confidence: 0.65
# Box: [ 33 108 640 479], Class: person, Confidence: 0.58
# Box: [  0 217 636 478], Class: bed, Confidence: 0.33
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 toothbrush, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 45 106 640 479], Class: person, Confidence: 0.55
# Box: [437 290 587 360], Class: toothbrush, Confidence: 0.35
# Box: [  1 288 640 478], Class: couch, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 toothbrush, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 45 106 640 479], Class: person, Confidence: 0.55
# Box: [437 290 587 360], Class: toothbrush, Confidence: 0.35
# Box: [  1 288 640 478], Class: couch, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 12.9ms
# Speed: 1.0ms preprocess, 12.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 50 104 640 479], Class: person, Confidence: 0.57
# Box: [  1 288 638 479], Class: bed, Confidence: 0.35
# Box: [  1 197 637 478], Class: bed, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 50 104 640 479], Class: person, Confidence: 0.57
# Box: [  1 288 638 479], Class: bed, Confidence: 0.35
# Box: [  1 197 637 478], Class: bed, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 12.4ms
# Speed: 2.2ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 28 104 640 479], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 15.2ms
# Speed: 3.0ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 28 104 640 479], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 17.0ms
# Speed: 1.0ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 21 103 639 479], Class: person, Confidence: 0.56
# Box: [  1 238 636 479], Class: bed, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 104 640 479], Class: person, Confidence: 0.62
# Box: [  1 148 637 478], Class: bed, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 18.1ms
# Speed: 1.1ms preprocess, 18.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 104 640 479], Class: person, Confidence: 0.62
# Box: [  1 148 637 478], Class: bed, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 bed, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 64 103 639 479], Class: person, Confidence: 0.61
# Box: [  1 289 640 479], Class: bed, Confidence: 0.39
# Box: [  1 284 640 479], Class: couch, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 1 bed, 10.5ms
# Speed: 1.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [ 64 103 639 479], Class: person, Confidence: 0.61
# Box: [  1 289 640 479], Class: bed, Confidence: 0.39
# Box: [  1 284 640 479], Class: couch, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 56 107 639 479], Class: person, Confidence: 0.68
# Frame written to output file
#
# 0: 480x640 1 person, 12.5ms
# Speed: 1.0ms preprocess, 12.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 56 107 639 479], Class: person, Confidence: 0.68
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 41 105 640 479], Class: person, Confidence: 0.55
# Box: [  1 288 639 479], Class: bed, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 41 105 640 479], Class: person, Confidence: 0.55
# Box: [  1 288 639 479], Class: bed, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 11.5ms
# Speed: 1.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 26 103 639 479], Class: person, Confidence: 0.58
# Box: [  1 289 639 479], Class: bed, Confidence: 0.30
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 26 103 639 479], Class: person, Confidence: 0.58
# Box: [  1 289 639 479], Class: bed, Confidence: 0.30
# Frame written to output file
#
# 0: 480x640 1 person, 13.6ms
# Speed: 1.0ms preprocess, 13.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 83 106 640 479], Class: person, Confidence: 0.77
# Frame written to output file
#
# 0: 480x640 1 person, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [121 107 640 479], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [121 107 640 479], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 15.8ms
# Speed: 1.0ms preprocess, 15.8ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [115 110 638 479], Class: person, Confidence: 0.68
# Box: [  0 281 640 479], Class: couch, Confidence: 0.35
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 17.3ms
# Speed: 2.5ms preprocess, 17.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [115 110 638 479], Class: person, Confidence: 0.68
# Box: [  0 281 640 479], Class: couch, Confidence: 0.35
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 35 112 639 479], Class: person, Confidence: 0.64
# Box: [  0 277 640 479], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 18.4ms
# Speed: 2.0ms preprocess, 18.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 35 112 639 479], Class: person, Confidence: 0.64
# Box: [  0 277 640 479], Class: couch, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 1 person, 17.5ms
# Speed: 1.9ms preprocess, 17.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 11 114 639 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 11 114 639 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 12.2ms
# Speed: 2.2ms preprocess, 12.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  2 117 639 480], Class: person, Confidence: 0.78
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 120 638 479], Class: person, Confidence: 0.67
# Box: [  0 250 637 479], Class: bed, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 15.7ms
# Speed: 2.6ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 120 638 479], Class: person, Confidence: 0.67
# Box: [  0 250 637 479], Class: bed, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.8ms
# Speed: 3.5ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 119 640 479], Class: person, Confidence: 0.70
# Box: [  0 279 640 478], Class: bed, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 119 640 479], Class: person, Confidence: 0.70
# Box: [  0 279 640 478], Class: bed, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 16 119 640 479], Class: person, Confidence: 0.68
# Frame written to output file
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 16 119 640 479], Class: person, Confidence: 0.68
# Frame written to output file
#
# 0: 480x640 1 person, 13.6ms
# Speed: 1.9ms preprocess, 13.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 30 113 639 478], Class: person, Confidence: 0.80
# Frame written to output file
#
# 0: 480x640 1 person, 8.5ms
# Speed: 3.0ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  6 115 638 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.5ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  6 115 638 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 15 116 638 480], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 12.1ms
# Speed: 0.5ms preprocess, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 15 116 638 480], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 8.0ms
# Speed: 1.1ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 39 114 638 480], Class: person, Confidence: 0.71
# Frame written to output file
#
# 0: 480x640 1 person, 15.8ms
# Speed: 1.5ms preprocess, 15.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 39 114 638 480], Class: person, Confidence: 0.71
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 17 115 638 480], Class: person, Confidence: 0.70
# Box: [  1 287 640 479], Class: couch, Confidence: 0.42
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 8.1ms
# Speed: 1.0ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 17 115 638 480], Class: person, Confidence: 0.70
# Box: [  1 287 640 479], Class: couch, Confidence: 0.42
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 16 116 638 480], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 8.1ms
# Speed: 1.5ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 16 116 638 480], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 8.2ms
# Speed: 1.7ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  8 116 638 480], Class: person, Confidence: 0.66
# Box: [  1 287 635 478], Class: couch, Confidence: 0.33
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 9.2ms
# Speed: 1.1ms preprocess, 9.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  8 116 638 480], Class: person, Confidence: 0.66
# Box: [  1 287 635 478], Class: couch, Confidence: 0.33
# Frame written to output file
#
# 0: 480x640 1 person, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  5 116 639 480], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  5 116 639 480], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 20 118 639 480], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 17.0ms
# Speed: 2.5ms preprocess, 17.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 20 118 639 480], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 15.4ms
# Speed: 2.2ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 34 118 638 480], Class: person, Confidence: 0.71
# Frame written to output file
#
# 0: 480x640 1 person, 18.0ms
# Speed: 2.5ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 34 118 638 480], Class: person, Confidence: 0.71
# Frame written to output file
#
# 0: 480x640 1 person, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 18 118 639 480], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 20.3ms
# Speed: 1.0ms preprocess, 20.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 18 118 639 480], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 11.6ms
# Speed: 2.0ms preprocess, 11.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 25 114 639 479], Class: person, Confidence: 0.69
# Box: [  0 283 640 478], Class: bed, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 19.6ms
# Speed: 1.5ms preprocess, 19.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  3 110 640 479], Class: person, Confidence: 0.62
# Box: [  0 155 636 478], Class: bed, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  3 110 640 479], Class: person, Confidence: 0.62
# Box: [  0 155 636 478], Class: bed, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 13.5ms
# Speed: 2.0ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 109 636 479], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 9.5ms
# Speed: 1.0ms preprocess, 9.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 109 636 479], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 13.0ms
# Speed: 1.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 109 639 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 12.6ms
# Speed: 1.0ms preprocess, 12.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 109 639 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 8.0ms
# Speed: 1.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  1 109 639 479], Class: person, Confidence: 0.65
# Box: [  1 179 640 478], Class: bed, Confidence: 0.26
# Box: [  0 286 636 478], Class: bed, Confidence: 0.25
# Frame written to output file
#
# 0: 480x640 1 person, 2 beds, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  1 109 639 479], Class: person, Confidence: 0.65
# Box: [  1 179 640 478], Class: bed, Confidence: 0.26
# Box: [  0 286 636 478], Class: bed, Confidence: 0.25
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 8.9ms
# Speed: 1.6ms preprocess, 8.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 109 636 478], Class: person, Confidence: 0.55
# Box: [  0 284 639 477], Class: bed, Confidence: 0.53
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 13.7ms
# Speed: 1.0ms preprocess, 13.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 109 636 478], Class: person, Confidence: 0.55
# Box: [  0 284 639 477], Class: bed, Confidence: 0.53
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 8.6ms
# Speed: 1.0ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 110 639 479], Class: person, Confidence: 0.71
# Box: [  1 226 640 477], Class: bed, Confidence: 0.34
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 17.1ms
# Speed: 1.0ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  1 110 639 479], Class: person, Confidence: 0.71
# Box: [  1 226 640 477], Class: bed, Confidence: 0.34
# Frame written to output file
#
# 0: 480x640 1 person, 9.7ms
# Speed: 0.9ms preprocess, 9.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  2 108 639 478], Class: person, Confidence: 0.61
# Frame written to output file
#
# 0: 480x640 1 person, 9.7ms
# Speed: 1.0ms preprocess, 9.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  2 108 639 478], Class: person, Confidence: 0.61
# Frame written to output file
#
# 0: 480x640 1 person, 10.0ms
# Speed: 1.0ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  2 108 639 478], Class: person, Confidence: 0.54
# Frame written to output file
#
# 0: 480x640 1 person, 14.5ms
# Speed: 1.0ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  3 107 638 479], Class: person, Confidence: 0.77
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 12.3ms
# Speed: 2.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 108 638 477], Class: person, Confidence: 0.66
# Box: [  2 105 640 478], Class: bed, Confidence: 0.53
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 10.7ms
# Speed: 1.1ms preprocess, 10.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 112 637 478], Class: bed, Confidence: 0.66
# Box: [  0 108 638 477], Class: person, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 17.8ms
# Speed: 3.1ms preprocess, 17.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 112 637 478], Class: bed, Confidence: 0.66
# Box: [  0 108 638 477], Class: person, Confidence: 0.27
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 113 637 478], Class: bed, Confidence: 0.72
# Box: [  0 108 637 477], Class: person, Confidence: 0.50
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 10.7ms
# Speed: 2.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 113 637 478], Class: bed, Confidence: 0.72
# Box: [  0 108 637 477], Class: person, Confidence: 0.50
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 107 637 477], Class: person, Confidence: 0.78
# Box: [  1 105 640 478], Class: bed, Confidence: 0.45
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.8ms
# Speed: 3.0ms preprocess, 16.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 107 637 477], Class: person, Confidence: 0.78
# Box: [  1 105 640 478], Class: bed, Confidence: 0.45
# Frame written to output file
#
# 0: 480x640 1 person, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 103 638 478], Class: person, Confidence: 0.83
# Frame written to output file
#
# 0: 480x640 1 person, 14.0ms
# Speed: 2.5ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 102 638 477], Class: person, Confidence: 0.83
# Frame written to output file
#
# 0: 480x640 1 person, 13.0ms
# Speed: 3.1ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 107 637 479], Class: person, Confidence: 0.81
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 13.8ms
# Speed: 4.2ms preprocess, 13.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  2 105 639 479], Class: person, Confidence: 0.87
# Box: [427 148 639 316], Class: cell phone, Confidence: 0.83
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  2 105 639 479], Class: person, Confidence: 0.87
# Box: [427 148 639 316], Class: cell phone, Confidence: 0.83
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 106 640 479], Class: person, Confidence: 0.86
# Box: [418 147 640 314], Class: cell phone, Confidence: 0.60
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 106 640 479], Class: person, Confidence: 0.86
# Box: [418 147 640 314], Class: cell phone, Confidence: 0.60
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 15.5ms
# Speed: 5.5ms preprocess, 15.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 106 640 479], Class: person, Confidence: 0.87
# Box: [407 144 640 314], Class: cell phone, Confidence: 0.49
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 106 640 479], Class: person, Confidence: 0.87
# Box: [407 144 640 314], Class: cell phone, Confidence: 0.49
# Frame written to output file
#
# 0: 480x640 1 person, 1 bottle, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 105 638 479], Class: person, Confidence: 0.86
# Box: [371 139 639 305], Class: bottle, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 bottle, 16.7ms
# Speed: 2.6ms preprocess, 16.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  0 105 638 479], Class: person, Confidence: 0.86
# Box: [371 139 639 305], Class: bottle, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 16.8ms
# Speed: 4.0ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 104 639 479], Class: person, Confidence: 0.77
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 106 637 478], Class: person, Confidence: 0.52
# Frame written to output file
#
# 0: 480x640 1 person, 17.8ms
# Speed: 3.5ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 106 637 478], Class: person, Confidence: 0.52
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 22.6ms
# Speed: 3.1ms preprocess, 22.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  0 104 637 479], Class: person, Confidence: 0.32
# Box: [ 52 228 124 278], Class: person, Confidence: 0.29
# Box: [  3 288 638 479], Class: bed, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 10.0ms
# Speed: 2.5ms preprocess, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [  0 104 637 479], Class: person, Confidence: 0.32
# Box: [ 52 228 124 278], Class: person, Confidence: 0.29
# Box: [  3 288 638 479], Class: bed, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 1 cell phone, 12.3ms
# Speed: 2.2ms preprocess, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected 4 objects
# Box: [322 159 639 343], Class: cell phone, Confidence: 0.75
# Box: [303 101 638 467], Class: person, Confidence: 0.32
# Box: [  2 288 636 479], Class: bed, Confidence: 0.28
# Box: [ 15  99 638 478], Class: person, Confidence: 0.26
# Frame written to output file
#
# 0: 480x640 2 persons, 1 cell phone, 13.1ms
# Speed: 2.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [323 162 639 345], Class: cell phone, Confidence: 0.53
# Box: [  0  98 639 479], Class: person, Confidence: 0.37
# Box: [318 104 639 370], Class: person, Confidence: 0.35
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [324 169 640 345], Class: cell phone, Confidence: 0.70
# Box: [307 102 638 464], Class: person, Confidence: 0.31
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 10.6ms
# Speed: 1.1ms preprocess, 10.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [324 169 640 345], Class: cell phone, Confidence: 0.70
# Box: [307 102 638 464], Class: person, Confidence: 0.31
# Frame written to output file
#
# 0: 480x640 2 persons, 1 cell phone, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [323 169 640 345], Class: cell phone, Confidence: 0.67
# Box: [308 106 640 470], Class: person, Confidence: 0.45
# Box: [  0 105 636 479], Class: person, Confidence: 0.30
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 cell phone, 18.8ms
# Speed: 3.1ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [323 168 640 345], Class: cell phone, Confidence: 0.58
# Box: [295 102 639 465], Class: person, Confidence: 0.35
# Box: [  2 288 636 479], Class: bed, Confidence: 0.34
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 cell phone, 15.5ms
# Speed: 4.5ms preprocess, 15.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [323 168 640 345], Class: cell phone, Confidence: 0.58
# Box: [295 102 639 465], Class: person, Confidence: 0.35
# Box: [  2 288 636 479], Class: bed, Confidence: 0.34
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 20.2ms
# Speed: 3.0ms preprocess, 20.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [321 167 640 347], Class: cell phone, Confidence: 0.64
# Box: [304 101 639 467], Class: person, Confidence: 0.41
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 18.7ms
# Speed: 5.1ms preprocess, 18.7ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [321 167 640 347], Class: cell phone, Confidence: 0.64
# Box: [304 101 639 467], Class: person, Confidence: 0.41
# Frame written to output file
#
# 0: 480x640 2 persons, 1 bed, 1 cell phone, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 4 objects
# Box: [322 168 640 347], Class: cell phone, Confidence: 0.64
# Box: [309 105 640 467], Class: person, Confidence: 0.48
# Box: [  2 287 636 479], Class: bed, Confidence: 0.31
# Box: [  0 105 637 479], Class: person, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 cell phone, 14.1ms
# Speed: 4.0ms preprocess, 14.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [322 167 640 348], Class: cell phone, Confidence: 0.51
# Box: [305 102 639 463], Class: person, Confidence: 0.31
# Box: [  3 288 637 479], Class: bed, Confidence: 0.29
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 cell phone, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [322 167 640 346], Class: cell phone, Confidence: 0.53
# Box: [302 102 639 459], Class: person, Confidence: 0.37
# Box: [  3 288 635 479], Class: bed, Confidence: 0.31
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 1 cell phone, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [322 167 640 346], Class: cell phone, Confidence: 0.53
# Box: [302 102 639 459], Class: person, Confidence: 0.37
# Box: [  3 288 635 479], Class: bed, Confidence: 0.31
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 14.1ms
# Speed: 4.4ms preprocess, 14.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [324 169 640 344], Class: cell phone, Confidence: 0.62
# Box: [  0  93 640 479], Class: person, Confidence: 0.34
# Frame written to output file
#
# 0: 480x640 2 persons, 1 cell phone, 14.5ms
# Speed: 2.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [322 169 640 341], Class: cell phone, Confidence: 0.58
# Box: [ 25  98 639 479], Class: person, Confidence: 0.43
# Box: [313 105 638 467], Class: person, Confidence: 0.30
# Frame written to output file
#
# 0: 480x640 2 persons, 1 cell phone, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 3 objects
# Box: [322 169 640 341], Class: cell phone, Confidence: 0.58
# Box: [ 25  98 639 479], Class: person, Confidence: 0.43
# Box: [313 105 638 467], Class: person, Confidence: 0.30
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [321 160 640 339], Class: cell phone, Confidence: 0.65
# Box: [  0 103 638 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 1 cell phone, 17.6ms
# Speed: 3.0ms preprocess, 17.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [321 160 640 339], Class: cell phone, Confidence: 0.65
# Box: [  0 103 638 479], Class: person, Confidence: 0.64
# Frame written to output file
#
# 0: 480x640 1 person, 11.1ms
# Speed: 3.5ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 105 640 480], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 105 640 480], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [112 103 640 479], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [112 103 640 479], Class: person, Confidence: 0.75
# Frame written to output file
#
# 0: 480x640 1 person, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [107  97 640 479], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 18.2ms
# Speed: 2.6ms preprocess, 18.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 43 104 638 479], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 1 person, 16.8ms
# Speed: 3.1ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 43 104 638 479], Class: person, Confidence: 0.69
# Frame written to output file
#
# 0: 480x640 2 persons, 13.2ms
# Speed: 3.6ms preprocess, 13.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  8 106 639 480], Class: person, Confidence: 0.59
# Box: [206 105 639 480], Class: person, Confidence: 0.29
# Frame written to output file
#
# 0: 480x640 2 persons, 21.8ms
# Speed: 3.6ms preprocess, 21.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [  8 106 639 480], Class: person, Confidence: 0.59
# Box: [206 105 639 480], Class: person, Confidence: 0.29
# Frame written to output file
#
# 0: 480x640 1 person, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  7 106 639 480], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  7 106 639 480], Class: person, Confidence: 0.72
# Frame written to output file
#
# 0: 480x640 1 person, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [106 107 640 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 10.4ms
# Speed: 3.2ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [106 107 640 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 17.1ms
# Speed: 3.0ms preprocess, 17.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [110 106 640 479], Class: person, Confidence: 0.68
# Box: [  0 274 640 480], Class: couch, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [106 105 639 479], Class: person, Confidence: 0.67
# Box: [  0 286 640 479], Class: couch, Confidence: 0.54
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 19.7ms
# Speed: 3.4ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [106 105 639 479], Class: person, Confidence: 0.67
# Box: [  0 286 640 479], Class: couch, Confidence: 0.54
# Frame written to output file
#
# 0: 480x640 1 person, 14.5ms
# Speed: 3.5ms preprocess, 14.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 96 102 640 478], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 17.7ms
# Speed: 2.9ms preprocess, 17.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 96 102 640 478], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 14.8ms
# Speed: 3.4ms preprocess, 14.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 91 101 640 479], Class: person, Confidence: 0.66
# Frame written to output file
#
# 0: 480x640 1 person, 15.3ms
# Speed: 3.3ms preprocess, 15.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 91 101 640 479], Class: person, Confidence: 0.66
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 96 100 640 479], Class: person, Confidence: 0.60
# Box: [  0 287 640 479], Class: couch, Confidence: 0.43
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 13.5ms
# Speed: 2.5ms preprocess, 13.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 96 100 640 479], Class: person, Confidence: 0.60
# Box: [  0 287 640 479], Class: couch, Confidence: 0.43
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 18.6ms
# Speed: 4.0ms preprocess, 18.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 99 101 640 479], Class: person, Confidence: 0.66
# Box: [  0 283 640 480], Class: couch, Confidence: 0.36
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 18.8ms
# Speed: 4.0ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 98 103 640 478], Class: person, Confidence: 0.71
# Box: [  0 283 640 479], Class: couch, Confidence: 0.28
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 18.3ms
# Speed: 4.5ms preprocess, 18.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 56 106 640 479], Class: person, Confidence: 0.67
# Box: [  0 280 640 480], Class: couch, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 56 106 640 479], Class: person, Confidence: 0.67
# Box: [  0 280 640 480], Class: couch, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 56 106 640 479], Class: person, Confidence: 0.67
# Box: [  0 280 640 480], Class: couch, Confidence: 0.32
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.4ms
# Speed: 2.7ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 98 103 640 479], Class: person, Confidence: 0.70
# Box: [  0 279 640 480], Class: couch, Confidence: 0.31
# Frame written to output file
#
# 0: 480x640 1 person, 11.1ms
# Speed: 3.0ms preprocess, 11.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 93 104 640 479], Class: person, Confidence: 0.70
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.3ms
# Speed: 1.6ms preprocess, 11.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 31 105 639 479], Class: person, Confidence: 0.68
# Box: [  0 284 640 479], Class: couch, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.4ms
# Speed: 2.2ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 31 105 639 479], Class: person, Confidence: 0.68
# Box: [  0 284 640 479], Class: couch, Confidence: 0.40
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 77 106 639 479], Class: person, Confidence: 0.68
# Box: [  0 282 640 480], Class: couch, Confidence: 0.37
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 77 106 639 479], Class: person, Confidence: 0.68
# Box: [  0 282 640 480], Class: couch, Confidence: 0.37
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 16.5ms
# Speed: 4.0ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 77 106 639 479], Class: person, Confidence: 0.68
# Box: [  0 282 640 480], Class: couch, Confidence: 0.37
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 12.3ms
# Speed: 3.0ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 45 107 639 479], Class: person, Confidence: 0.59
# Box: [  1 286 640 479], Class: couch, Confidence: 0.44
# Frame written to output file
#
# 0: 480x640 1 person, 1 couch, 17.2ms
# Speed: 4.1ms preprocess, 17.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [ 45 107 639 479], Class: person, Confidence: 0.59
# Box: [  1 286 640 479], Class: couch, Confidence: 0.44
# Frame written to output file
#
# 0: 480x640 1 person, 1 bed, 16.5ms
# Speed: 2.9ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 2 objects
# Box: [151 103 638 480], Class: person, Confidence: 0.56
# Box: [  3 288 640 479], Class: bed, Confidence: 0.49
# Frame written to output file
#
# 0: 480x640 1 person, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  0 103 636 479], Class: person, Confidence: 0.68
# Frame written to output file
#
# 0: 480x640 1 person, 15.7ms
# Speed: 3.9ms preprocess, 15.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  6 102 635 480], Class: person, Confidence: 0.60
# Frame written to output file
#
# 0: 480x640 1 person, 13.4ms
# Speed: 3.5ms preprocess, 13.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  6 102 635 480], Class: person, Confidence: 0.60
# Frame written to output file
#
# 0: 480x640 1 person, 16.2ms
# Speed: 4.0ms preprocess, 16.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [ 26 105 639 479], Class: person, Confidence: 0.66
# Frame written to output file
#
# 0: 480x640 1 person, 13.0ms
# Speed: 3.5ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 104 638 480], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 16.5ms
# Speed: 3.5ms preprocess, 16.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  8 102 640 480], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 14.6ms
# Speed: 3.6ms preprocess, 14.6ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  8 102 640 480], Class: person, Confidence: 0.67
# Frame written to output file
#
# 0: 480x640 1 person, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 104 635 480], Class: person, Confidence: 0.71
# Frame written to output file
#
# 0: 480x640 1 person, 13.3ms
# Speed: 4.7ms preprocess, 13.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Detected 1 objects
# Box: [  1 104 635 480], Class: person, Confidence: 0.71
# Frame written to output file
# Recording stopped by user
# Recording stopped and video saved at c:\Users\alway\OneDrive\Documents\GitHub\Applied-AI\hw2\yolo\yolo-output.mp4
