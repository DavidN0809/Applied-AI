# %%
import cv2
import numpy as np
import torch
import torchvision
import time
from torchvision import transforms as T
from torchvision.models.detection import maskrcnn_resnet50_fpn_v2, MaskRCNN_ResNet50_FPN_V2_Weights
import os

# %%
def rcnnwebcam(model_path, output_file='rcnn-output.mp4', fps=20.0, frame_size=(640, 480)):
    # Load the Mask R-CNN model
    weights = MaskRCNN_ResNet50_FPN_V2_Weights.COCO_V1
    model = maskrcnn_resnet50_fpn_v2(weights=weights)
    model.load_state_dict(torch.load(model_path))
    model.eval()  # Set the model to evaluation mode
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Open the webcam
    vc = cv2.VideoCapture(0)
    vc.set(cv2.CAP_PROP_FRAME_WIDTH, frame_size[0])
    vc.set(cv2.CAP_PROP_FRAME_HEIGHT, frame_size[1])

    # Define variables for VideoWriter initialization
    out = None
    recording = False
    output_path = os.path.abspath(output_file)  # Get the absolute path of the output file

    # Automatically start recording
    # Define the codec and create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Using 'mp4v' codec
    out = cv2.VideoWriter(output_file, fourcc, fps, frame_size)

    # Check if VideoWriter opened successfully
    if not out.isOpened():
        print("Failed to open VideoWriter")
        return  # Exit the function if VideoWriter fails
    else:
        recording = True
        print(f"Recording started... Saving video to: {output_path}")

    # Define the image transformations
    transform = T.Compose([T.ToTensor()])

    while True:
        ret, frame = vc.read()
        if not ret:
            print("Failed to capture frame")
            break

        # Measure time for preprocessing
        start_preprocess = time.time()
        img_tensor = transform(frame).to(device)
        img_tensor = img_tensor.unsqueeze(0)  # Add batch dimension
        end_preprocess = time.time()

        # Run Mask R-CNN inference
        start_inference = time.time()
        with torch.no_grad():
            predictions = model(img_tensor)
        end_inference = time.time()

        # Measure time for postprocessing
        start_postprocess = time.time()
        boxes = predictions[0]['boxes'].cpu().numpy()  # Bounding boxes
        scores = predictions[0]['scores'].cpu().numpy()  # Confidence scores
        labels = predictions[0]['labels'].cpu().numpy()  # Class labels

        # Filter out low-confidence detections (e.g., score > 0.25)
        threshold = 0.25
        detected_objects = 0
        for i, box in enumerate(boxes):
            if scores[i] > threshold:
                detected_objects += 1
                x1, y1, x2, y2 = box.astype(int)
                label = f'Class {labels[i]}: {scores[i]:.2f}'
                color = (0, 255, 0)  # Green color for bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
                print(f"Box: [{x1} {y1} {x2} {y2}], Class: {labels[i]}, Confidence: {scores[i]:.2f}")
        end_postprocess = time.time()

        # Print detection summary
        print(f"0: {frame_size[1]}x{frame_size[0]} {detected_objects} object(s) detected, {end_inference - start_inference:.1f}ms")
        print(f"Speed: {(end_preprocess - start_preprocess) * 1000:.1f}ms preprocess, {(end_inference - start_inference) * 1000:.1f}ms inference, {(end_postprocess - start_postprocess) * 1000:.1f}ms postprocess per image at shape {img_tensor.shape}")

        # Show the frame
        cv2.imshow("Mask R-CNN Webcam", frame)

        # Write the frame to the output file
        if recording and out is not None:
            # Ensure the frame size matches the VideoWriter frame size
            resized_frame = cv2.resize(frame, frame_size)
            out.write(resized_frame)
            print("Frame written to output file")

        # Capture key press
        key = cv2.waitKey(1) & 0xFF

        # Check if 'q' is pressed to stop
        if key == ord('q'):
            print("Recording stopped by user")
            break

    # Release resources
    vc.release()
    if out is not None:
        out.release()
        # Verify if the file was created
        if os.path.exists(output_path) and os.path.getsize(output_path) > 0:
            print(f"Recording stopped and video saved at {output_path}")
        else:
            print(f"Failed to save the video or the file is empty at {output_path}")
    cv2.destroyAllWindows()

# %%
# Load and run the Mask R-CNN webcam function
model_path = './mask_rcnn_coco.pth'
rcnnwebcam(model_path)
# Out:
# C:\Users\alway\AppData\Local\Temp\ipykernel_2284\2883102829.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
#
ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [259 0 606 480], Class: 1, Confidence: 0.35
# Box: [85 129 154 186], Class: 1, Confidence: 0.26
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 1.0ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [88 129 154 185], Class: 1, Confidence: 0.39
# Box: [117 16 625 480], Class: 1, Confidence: 0.37
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 1.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [134 14 631 480], Class: 1, Confidence: 0.36
# Box: [88 130 154 185], Class: 1, Confidence: 0.28
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 3.5ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [133 12 626 480], Class: 1, Confidence: 0.35
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 84.6ms inference, 0.5ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [133 12 626 480], Class: 1, Confidence: 0.35
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 1.0ms preprocess, 94.4ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [109 11 628 480], Class: 1, Confidence: 0.36
# Box: [88 129 153 185], Class: 1, Confidence: 0.26
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 6.5ms preprocess, 84.0ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [87 130 150 184], Class: 1, Confidence: 0.39
# Box: [289 0 617 480], Class: 1, Confidence: 0.35
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 88.6ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [100 7 628 480], Class: 1, Confidence: 0.39
# Box: [89 130 151 185], Class: 1, Confidence: 0.32
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 3.0ms preprocess, 90.2ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [103 13 631 480], Class: 1, Confidence: 0.37
# Box: [86 129 152 186], Class: 1, Confidence: 0.27
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 93.8ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [195 48 627 480], Class: 1, Confidence: 0.36
# Box: [86 129 153 186], Class: 1, Confidence: 0.28
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 4.5ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [114 11 625 480], Class: 1, Confidence: 0.37
# Box: [86 129 152 185], Class: 1, Confidence: 0.32
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 1.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [86 130 154 186], Class: 1, Confidence: 0.38
# Box: [120 15 626 480], Class: 1, Confidence: 0.37
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 6.6ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [250 0 579 480], Class: 1, Confidence: 0.38
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 82.7ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [106 15 629 480], Class: 1, Confidence: 0.41
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 3.0ms preprocess, 90.4ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [117 16 631 480], Class: 1, Confidence: 0.36
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 4.0ms preprocess, 83.5ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [117 16 631 480], Class: 1, Confidence: 0.36
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 3.1ms preprocess, 83.0ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [254 0 580 480], Class: 1, Confidence: 0.39
# 0: 480x640 1 object(s) detected, 0.1ms
# Speed: 5.0ms preprocess, 82.0ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [99 9 629 480], Class: 1, Confidence: 0.40
# Box: [88 131 153 186], Class: 1, Confidence: 0.30
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [108 14 627 480], Class: 1, Confidence: 0.41
# Box: [87 131 153 186], Class: 1, Confidence: 0.36
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 6.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [94 13 627 480], Class: 1, Confidence: 0.40
# Box: [90 131 154 186], Class: 1, Confidence: 0.29
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 2.0ms preprocess, 89.4ms inference, 0.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Box: [107 14 629 480], Class: 1, Confidence: 0.44
# Box: [88 130 154 187], Class: 1, Confidence: 0.26
# 0: 480x640 2 object(s) detected, 0.1ms
# Speed: 3.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape torch.Size([1, 3, 480, 640])
# Frame written to output file
# Recording stopped by user
# Recording stopped and video saved at c:\Users\alway\OneDrive\Documents\GitHub\Applied-AI\hw2\rcnn\rcnn-output.mp4
